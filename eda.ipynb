# %%
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_csv('static/2023_APR.csv', index_col=0)

# %% [markdown]
# ## Summary of actions before training
#
# 1. There is collinearity between floor_area_sqm and rooms, we should only use one of these features

# %% [markdown]
# ### Checking for collinearity

# %%
impt_features = df[['resale_price', 'floor_area_sqm', 'remaining_lease', 'rooms', 'avg_storey']]
sns.heatmap(impt_features.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(impt_features)

# %% [markdown]
# ### Remove null values

# %%
display(df.isna().sum())
df.dropna(axis=1, inplace=True)
# Out:
# town                    0
# flat_type               0
# flat_model              0
# floor_area_sqm          0
# street_name             0
# resale_price            0
# month                   0
# remaining_lease         0
# lease_commence_date     0
# storey_range            0
# block                   0
# rooms                   0
# avg_storey              0
# timeseries_month        0
# year                    0
# original_street_name    0
# region                  0
# position                7
# dtype: int64
